# %% [markdown]
# ## Data Science Problem

# %% [markdown]
# If next year looks like this year, what are projected sales for next year and what can we do to change that?

# %% [markdown]
# ## Objectives

# %% [markdown]
# Create a sales predictor model that allows you to try different variables and predict more accurate sales
# <br><br>Will also want to track sales by sales channel/growth by sales channel

# %% [markdown]
# ## 1 Imports

# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2 Load Data and convert to dataframe

# %%
sales_df = pd.read_csv('sales_2020-08-01_2023-09-06.csv')

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3228 entries, 0 to 3227
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          3228 non-null   int64
#  1   Sale ID           3228 non-null   int64
#  2   Date              3228 non-null   object
#  3   Order             3228 non-null   object
#  4   Transaction type  3228 non-null   object
#  5   Sale type         3228 non-null   object
#  6   Sales channel     3228 non-null   object
#  7   POS location      679 non-null    object
#  8   Billing country   2549 non-null   object
#  9   Billing region    2542 non-null   object
#  10  Billing city      2549 non-null   object
#  11  Shipping country  2532 non-null   object
#  12  Shipping region   2525 non-null   object
#  13  Shipping city     2532 non-null   object
#  14  Product type      2010 non-null   object
#  15  Product vendor    2291 non-null   object
#  16  Product           2301 non-null   object
#  17  Variant           603 non-null    object
#  18  Variant SKU       2074 non-null   object
#  19  Net quantity      3228 non-null   int64
#  20  Gross sales       3228 non-null   float64
#  21  Discounts         3228 non-null   float64
#  22  Returns           3228 non-null   float64
#  23  Net sales         3228 non-null   float64
#  24  Shipping          3228 non-null   float64
#  25  Taxes             3228 non-null   float64
#  26  Total sales       3228 non-null   float64
# dtypes: float64(7), int64(3), object(17)
# memory usage: 681.0+ KB

# %%
pd.set_option('display.max_columns', None)

sales_df.head()
# Out:
#         Order ID        Sale ID                       Date  Order  \
# 0  2468022255679  7500145655871  2020-08-08T20:00:19-04:00  #1254
# 1  2468022255679  7500145688639  2020-08-08T20:00:19-04:00  #1254
# 2  2468022255679  7500157288511  2020-08-08T20:03:42-04:00  #1254
# 3  2468022255679  7500157255743  2020-08-08T20:03:42-04:00  #1254
# 4  2469497241663  7505168695359  2020-08-09T12:04:57-04:00  #1255
#
#   Transaction type Sale type Sales channel POS location Billing country  \
# 0          product     order  Online Store          NaN   United States
# 1         shipping     order  Online Store          NaN   United States
# 2          product    return  Online Store          NaN   United States
# 3         shipping    return  Online Store          NaN   United States
# 4          product     order  Online Store          NaN   United States
#
#   Billing region Billing city Shipping country Shipping region Shipping city  \
# 0   Pennsylvania   Pittsburgh    United States    Pennsylvania    Pittsburgh
# 1   Pennsylvania   Pittsburgh    United States    Pennsylvania    Pittsburgh
# 2   Pennsylvania   Pittsburgh    United States    Pennsylvania    Pittsburgh
# 3   Pennsylvania   Pittsburgh    United States    Pennsylvania    Pittsburgh
# 4       Michigan      Redford    United States        Michigan       Redford
#
#      Product type    Product vendor  \
# 0  Hand Dyed Yarn  Ex Libris Fibers
# 1             NaN               NaN
# 2  Hand Dyed Yarn  Ex Libris Fibers
# 3             NaN               NaN
# 4  Hand Dyed Yarn  Ex Libris Fibers
#
#                                              Product Variant  \
# 0                                               TEST     NaN
# 1                                                NaN     NaN
# 2                                               TEST     NaN
# 3                                                NaN     NaN
# 4  My Abandonment -- Solnit Base (Superwash merin...     NaN
#
#              Variant SKU  Net quantity  Gross sales  Discounts  Returns  \
# 0                    NaN             1          1.0        0.0      0.0
# 1                    NaN             0          0.0        0.0      0.0
# 2                    NaN            -1          0.0        0.0     -1.0
# 3                    NaN             0          0.0        0.0      0.0
# 4  solnit-my-abandonment             1         23.0        0.0      0.0
#
#    Net sales  Shipping  Taxes  Total sales
# 0        1.0      0.00    0.0         1.00
# 1        0.0      3.71    0.0         3.71
# 2       -1.0      0.00    0.0        -1.00
# 3        0.0     -3.71    0.0        -3.71
# 4       23.0      0.00    0.0        23.00

# %% [markdown]
# ## 3 Explore the Data

# %%
sales_df.shape
# Out:
# (3228, 27)

# %%
sales_df.dtypes
# Out:
# Order ID              int64
# Sale ID               int64
# Date                 object
# Order                object
# Transaction type     object
# Sale type            object
# Sales channel        object
# POS location         object
# Billing country      object
# Billing region       object
# Billing city         object
# Shipping country     object
# Shipping region      object
# Shipping city        object
# Product type         object
# Product vendor       object
# Product              object
# Variant              object
# Variant SKU          object
# Net quantity          int64
# Gross sales         float64
# Discounts           float64
# Returns             float64
# Net sales           float64
# Shipping            float64
# Taxes               float64
# Total sales         float64
# dtype: object

# %% [markdown]
# ### 3.1 Convert dates

# %%
#change dates to datetime, since whatever else I do I will want that formatted
sales_df['Date'] = pd.to_datetime(sales_df['Date'], utc=True)

sales_df['Date'].dtypes
# Out:
# datetime64[ns, UTC]

# %% [markdown]
# ### 3.2 Identify key features

# %%
# what sales channels are being used?
sales_df['Sales channel'].unique()
# Out:
# array(['Online Store', 'Point of Sale', 'Shop'], dtype=object)

# %%
# vendor has three sales channels: Online Store (website), Point of Sale (purchases made in person at a yarn fair), 
# and Shop (purchases made at a brick-and-mortar store while being hosted as a visiting vendor)

sales_df['Sales channel'].replace({'Point of Sale' : 'Yarn Fair', 'Shop' : 'Shop Pop Up'}, inplace=True) 

sales_df['Sales channel'].unique()
# Out:
# array(['Online Store', 'Yarn Fair', 'Shop Pop Up'], dtype=object)

# %%
# relevant columns for me are: 
# 'Order ID' to see how many units/SKUs per order 
# 'Date'
# 'Transaction type' to sort shipping from products - check unknowns
# 'Sale type' to track orders and returns
# 'Sales channel' - 'Online Store' = website, 'Point of Sale' = trade show, 'Shop' = popup in a store
# 'Product type' - combine Gift Card and Gift Cards, check nans
# 'Product' - check nans
# 'Net quantity'
# 'Gross sales'
# 'Discounts'
# 'Returns'
# 'Net sales'
# 'Shipping'

# %%
# drop columns
sales_df = sales_df.drop(columns=['Sale ID', 'Order', 'POS location', 
       'Billing country', 'Billing region', 'Billing city', 'Shipping country', 'Shipping region', 'Shipping city',
       'Product vendor', 'Variant', 'Variant SKU', 'Taxes', 'Total sales'])

# %%
sales_df.select_dtypes('object')
# Out:
#      Transaction type Sale type Sales channel    Product type  \
# 0             product     order  Online Store  Hand Dyed Yarn
# 1            shipping     order  Online Store             NaN
# 2             product    return  Online Store  Hand Dyed Yarn
# 3            shipping    return  Online Store             NaN
# 4             product     order  Online Store  Hand Dyed Yarn
# ...               ...       ...           ...             ...
# 3223          product     order  Online Store  Hand Dyed Yarn
# 3224          product     order  Online Store  Hand Dyed Yarn
# 3225          product     order  Online Store            Yarn
# 3226         shipping     order  Online Store             NaN
# 3227          product     order  Online Store  Hand Dyed Yarn
#
#                                                 Product
# 0                                                  TEST
# 1                                                   NaN
# 2                                                  TEST
# 3                                                   NaN
# 4     My Abandonment -- Solnit Base (Superwash merin...
# ...                                                 ...
# 3223     Marble Staircase -- Shelley Base (NSW Worsted)
# 3224         Ordinary Evils -- Shirley Base (Fingering)
# 3225                       Queer Classics Sets & Skeins
# 3226                                                NaN
# 3227         Rusted Shelves -- Shirley Base (Fingering)
#
# [3228 rows x 5 columns]

# %% [markdown]
# ### 3.3 Identify Missing Values

# %%
sales_df.isna().sum()
# Out:
# Order ID               0
# Date                   0
# Transaction type       0
# Sale type              0
# Sales channel          0
# Product type        1218
# Product              927
# Net quantity           0
# Gross sales            0
# Discounts              0
# Returns                0
# Net sales              0
# Shipping               0
# dtype: int64

# %%
# What *is* in the columns that are missing values?
for col in sales_df:
    if sales_df[col].isna().sum() > 0:
        print(col, sales_df[col].unique())
# Out:
# Product type ['Hand Dyed Yarn' nan 'Monthly Yarn Club' 'Gift Card' 'Notions'
#  'Gift Cards' 'Yarn' 'Handknits' 'sticker']
# Product ['TEST' nan
#  'My Abandonment -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'The Goldfinch --  Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'Iron Lilac -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Acorn -- Jane Base (Merino/Silk; 2-ply Fingering Weight)'
#  'Wraith Tea No. 18 -- Solnit Base (Superwash Merino/nylon; 4ply Fingering Weight)'
#  'You Burn Me -- Ursula Base (Merino/Yak/Nylon; 3-ply Fingering Weight)'
#  'Jump Cannon -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Exquisite Corpse -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'Oathbreaker -- Solnit Base (Superwash Merino/Nylon; 4-ply Fingering Weight)'
#  'Stained Glass Forest -- Solnit Base (Superwash Merino/nylon; 4ply Fingering Weight)'
#  'Werelight -- Solnit Base (Superwash Merino/nylon; 4ply Fingering Weight)'
#  'Leviathan -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'You Burn Me -- Solnit Base (Superwash Merino/nylon; 4ply Fingering Weight)'
#  'Wraith Tea No. 16 -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Oathbreaker -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Stained Glass Forest -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Leviathan -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Wraith Tea No. 18 -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'The Yellow Wallpaper -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Jadis -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Wraith Tea No. 15 -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Exquisite Corpse -- Ursula Base (Merino/Yak/Nylon; 3-ply Fingering Weight)'
#  'Exquisite Corpse -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Weird Sisters Deconstructed (individual skeins) -- Preorder'
#  'Iron Lilac -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'NIMH -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'Oathbreaker -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'The Spectral Collection - September 2020 (Yak Sock base)'
#  'The Spectral Collection - September 2020 (Sock base)'
#  'The Spectral Collection - September 2020 (DK base)'
#  'Dracula -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Receiver of Memory -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'NIMH -- Simone Base (Superwash 100% Merino; 4 ply Fingering Weight)'
#  'Wraith Tea no. 13 -- Jane Base (Merino/Silk; 2-ply Fingering Weight)'
#  'Aureate -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'Weird Sisters -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'The Spectral Collection - October 2020 (Yak Sock base)'
#  'The Spectral Collection - October 2020 (DK base)'
#  'The Spectral Collection - October 2020 (Sock base)'
#  'Dracula -- Seconds! -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'Wraith Tea No. 22 --  Zilpha Base (Superwash U.S. Wool; 4 ply Worsted Weight)'
#  'Renfield -- Solnit Base (Superwash Merino/nylon; 4ply Fingering Weight Minis)'
#  'Ferdinand -- Solnit Base (Superwash Merino/nylon; 4ply Fingering Weight)'
#  'Dracula -- Solnit Base (Superwash Merino/nylon; 4ply Fingering Weight)'
#  'Ex Libris Fibers Gift Card'
#  'Exquisite Corpse -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'Renfield -- Solnit Base (Superwash Merino/nylon; 4ply Fingering Weight)'
#  'Wraith Tea no. 21 -- Solnit Base (Superwash Merino/nylon; 4ply Fingering Weight)'
#  'NIMH -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'The Yellow Wallpaper -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'Foxing -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Ferdinand -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'Wraith Tea no. 11 -- Simone Base (Superwash Merino; 4-ply Fingering Weight)'
#  'Mina Murray -- Jane Base (Merino/Silk; 2-ply Fingering Weight)'
#  'The Spectral Collection - November 2020 (Yak Sock base)'
#  'The Spectral Collection - November 2020 (Sock base)'
#  'Iron Lilac - Jane Base (Merino/Silk; 2-ply Fingering Weight)'
#  'The Spectral Collection - November 2020 (DK base)'
#  'Foxing -- Solnit Base (Superwash Merino/Nylon; 4-ply Fingering Weight)'
#  'Spiders in Her Hair -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'Wraith Tea no. 20 -- Solnit Base (Superwash Merino/nylon; 4ply Fingering Weight)'
#  'Wraith Tea No. 23 -- Solnit Base (Superwash Merino/nylon; 4ply Fingering Weight)'
#  'Wraith Tea No. 27 -- Solnit Base (Superwash Merino/nylon; 4ply Fingering Weight)'
#  'Wraith Tea No. 28 -- Solnit Base (Superwash Merino/nylon; 4ply Fingering Weight)'
#  'Wraith Tea No. 25 -- Solnit Base (Superwash Merino/nylon; 4ply Fingering Weight)'
#  'Spiders in Her Hair -- Seconds! -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'The Yellow Wallpaper -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'Wraith Tea no. 19 -- Solnit Base (Superwash Merino/nylon; 4ply Fingering Weight)'
#  'The Spectral Collection - Joyce Carol Oates (Yak Sock base)'
#  'The Spectral Collection - Margaret Atwood (Sock base)'
#  'The Spectral Collection - Joyce Carol Oates (Sock base)'
#  'The Spectral Collection - Margaret Atwood (Yak Sock base)'
#  'The Spectral Collection - Joyce Carol Oates (DK base)'
#  'The Spectral Collection - Margaret Atwood (DK base)'
#  'Wraith Tea No. 26 -- Solnit Base (Superwash Merino/nylon; 4ply Fingering Weight)'
#  'NIMH -- Ursula Base (Merino/Yak/Nylon; 3-ply Fingering Weight)'
#  'Wraith Tea no. 29 -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'Werelight (seconds) -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'Abyss of Indiscretion -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Mina Murray -- Ursula Base (Merino/Yak/Nylon; 3-ply Fingering Weight)'
#  'How Good To Fight Beside You (Seconds) -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'Moongrit -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Topiary -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Topiary -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'Werelight -- Ursula Base (Merino/Yak/Nylon; 3-ply Fingering Weight)'
#  'Abyss of Indiscretion -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'The Evil Garden -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'Wraith Tea No. 24 -- Solnit Base (Superwash Merino/nylon; 4ply Fingering Weight)'
#  'Abyss of Indiscretion -- Tartt Base (Superwash Merino; 3-ply Bulky Weight)'
#  'Mina Murray -- Tartt Base (Superwash Merino; 3-ply Bulky Weight)'
#  'The Blue Aspic -- Ursula Base (Merino/Yak/Nylon; 3-ply Fingering Weight)'
#  'Dracula -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'The Blue Aspic  -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Lavender Leotard -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'Ferdinand -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Topiary -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'Moongrit -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'You Burn Me -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'Wraith Tea No. 17 --  Zilpha Base (Superwash U.S. Wool; 4 ply Worsted Weight)'
#  'Granny Panties -- Jane Base (Merino/Silk; 2-ply Fingering Weight)'
#  'Moongrit -- Tartt Base (Superwash Merino; 3-ply Bulky Weight)'
#  'The Blue Aspic -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'The Blue Aspic -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'Topiary -- Tartt Base (Superwash Merino; 3-ply Bulky Weight)'
#  'Lavender Leotard -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Spiders in Her Hair -- Simone Base ( Superwash Merino; 4-ply Fingering Weight)'
#  'The Turn of the Screw - Sock - Gothic horror yarn club'
#  'The Turn of the Screw - Yak Sock - Gothic horror yarn club'
#  'The Turn of the Screw - DK - Gothic horror yarn club'
#  'The Blue Aspic -- Tartt Base (Superwash Merino; 3-ply Bulky Weight)'
#  'The Turn of the Screw - Worsted - Gothic horror yarn club'
#  'Eliza Furnace -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'Eliza Furnace -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Wraith Tea No. 31 -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Wraith Tea no. 30 -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'Jadis -- Tartt Base (Superwash Merino; 3-ply Bulky Weight)'
#  'Moongrit -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'Dracula -- Tartt Base (Superwash Merino; 3-ply Bulky Weight)'
#  'The Lifted Veil - Sock - Gothic horror yarn club - Preorder!'
#  'The Lifted Veil - Yak Sock - Gothic horror yarn club - Preorder!'
#  'The Lifted Veil - Worsted - Gothic horror yarn club - Preorder!'
#  'The Lifted Veil - DK - Gothic horror yarn club - Preorder!'
#  'Lavender Leotard -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'Exquisite Corpse -- Tartt Base (Superwash Merino; 3-ply Bulky Weight)'
#  'Wuthering Heights - Sock - Gothic horror yarn club - Preorder'
#  'Wuthering Heights - Yak Sock - Gothic horror yarn club - Preorder'
#  'Wuthering Heights - Worsted - Gothic horror yarn club - Preorder'
#  'Wuthering Heights - DK - Gothic horror yarn club - Preorder'
#  'Wuthering Heights - Gothic horror yarn club - 2nd Preorder'
#  'Wraith Tea No. 32 -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'The Evil Garden -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'Abyss of Indiscretion -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'The Fall of the House of Usher - Sock - Gothic horror yarn club - Preorder'
#  'The Fall of the House of Usher - Yak Sock - Gothic horror yarn club - Preorder'
#  'The Fall of the House of Usher - Worsted - Gothic horror yarn club - Preorder'
#  'The Fall of the House of Usher - DK - Gothic horror yarn club - Preorder'
#  'Spectral micro sets -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'Wraith Tea no. 33 -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'Wraith Tea no. 34 -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'Foxing -- Daphne Base (Superwash Merino; 2-ply Sport Weight)'
#  'The House of the Seven Gables - Sock - Gothic horror yarn club - Preorder'
#  'The House of the Seven Gables - DK - Gothic horror yarn club - Preorder'
#  'The House of the Seven Gables - Worsted - Gothic horror yarn club - Preorder'
#  'Wraith Tea no. 35 -- Ursula Base (Merino/Yak/Nylon; 3-ply Fingering Weight)'
#  'The House of the Seven Gables - Yak Sock - Gothic horror yarn club - Preorder'
#  'Grackle -- Anaïs Base (Superwash Merino/Silk; Single Ply Fingering Weight)'
#  'Sinister Premonitions -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'Wraith Tea no. 38 -- Anaïs Base (Superwash Merino/Silk; Single Ply Fingering Weight)'
#  'Witchgarden Flowers -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'Wraith Tea no. 39 -- Jane Base (Merino/Silk; 2-ply Fingering Weight)'
#  'The Timekeeper -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'Wraith Tea no. 36 -- Anaïs Base (Superwash Merino/Silk; Single Ply Fingering Weight)'
#  'Wuthering Heights -- Ursula Base (Merino/Yak/Nylon; 3-ply Fingering Weight)'
#  'Wraith Tea no. 35 -- Anaïs Base (Superwash Merino/Silk; Single Ply Fingering Weight)'
#  'You Burn Me -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Witchgarden Flowers -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Sinister Premonitions -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'The Picture of Dorian Gray - Sock - Gothic horror yarn club - Preorder'
#  'The Picture of Dorian Gray - Yak Sock - Gothic horror yarn club - Preorder'
#  'The Picture of Dorian Gray - DK - Gothic horror yarn club - Preorder'
#  'The Picture of Dorian Gray - Worsted - Gothic horror yarn club - Preorder'
#  'PREORDERS - Grackle -- Anaïs Base (Superwash Merino/Silk; Single Ply Fingering Weight)'
#  'Foxing -- Tartt Base (Superwash Merino; 3-ply Bulky Weight)'
#  'Goosebumps mini set (PREORDERS)' 'Fear Street Fade Set (PREORDERS)'
#  'Wraith Tea no. 40  -- Nonsuperwash Merino; 4-ply Worsted weight'
#  'The Picture of Dorian Gray -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'The Picture of Dorian Gray -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'The Picture of Dorian Gray -- Ursula Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'The House of the Seven Gables -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'The Timekeeper -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'Wraith Tea no. 37 -- Anaïs Base (Superwash Merino/Silk; Single Ply Fingering Weight)'
#  'Jadis -- Solnit Base (Superwash merino/nylon; 4ply Fingering Weight)'
#  'The Picture of Dorian Gray - Skull progress keeper'
#  'The Lifted Veil -- Ursula Base (Merino/Yak/Nylon; 3-ply Fingering Weight)'
#  'The Evil Garden -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'The House of the Seven Gables -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'My Abandonment -- Carson Base (Superwash Merino; 4-ply DK Weight)'
#  'The Evil Garden -- Tartt Base (Superwash Merino; 3-ply Bulky Weight)'
#  'Dracula -- Carson Base' 'Lavender Leotard -- Solnit Base'
#  'Bitchcraft -- Carson Base' 'Mina Murray -- Ursula Base'
#  'Renfield -- Carson Base' 'The Timekeeper -- Solnit Base'
#  'Grackle -- Anaïs Base' 'Bitchcraft -- Solnit Base'
#  'Renfield -- Ursula Base' 'The Fall of the House of Usher -- Carson Base'
#  'Topiary -- Anaïs Base' 'Mina Murray -- Carson Base'
#  'Exquisite Corpse -- Anaïs Base' 'Dracula -- Ursula Base'
#  'You Burn Me -- Carson Base' 'House of Leaves -- Solnit Base'
#  'Wraith Tea no. 42 -- Solnit Base' 'Dracula -- Solnit Base'
#  'Eliza Furnace -- Ursula Base' 'Exquisite Corpse -- Solnit Base'
#  'Exquisite Corpse -- Carson Base' 'Wuthering Heights -- Carson Base'
#  'Wuthering Heights -- Solnit Base' 'Mina Murray -- Solnit Base'
#  'Renfield -- Solnit Base' 'Foxing -- Solnit Base'
#  'House of Leaves -- Carson Base' 'Wuthering Heights -- Ursula Base'
#  'The Yellow Wallpaper -- Solnit Base' 'Eliza Furnace -- Carson Base'
#  'House of Leaves -- Ursula Base' 'Fahrenheit 451 -- Solnit Base'
#  'Ex Libris Bookplates - Set of 10' 'The Yellow Wallpaper -- Ursula Base'
#  'House of Leaves -- Solnit Base (Sock)'
#  'Eliza Furnace -- Solnit Base (Sock)' 'Renfield -- Solnit Base (Sock)'
#  'Exquisite Corpse -- Solnit Base (Sock)'
#  'Mina Murray -- Solnit Base (Sock)' 'Bitchcraft -- Solnit Base (sock)'
#  'Lavender Leotard -- Solnit Base (Sock)'
#  'Fahrenheit 451 -- Solnit Base (Sock)'
#  'The Fall of the House of Usher -- Solnit Base (Sock)'
#  'Wuthering Heights -- Solnit Base (Sock)'
#  'House of Leaves -- Ursula Base (Yak sock)'
#  'Mina Murray -- Carson Base (DK)' 'Foxing -- Solnit Base (Sock)'
#  'The Yellow Wallpaper -- Solnit Base (Sock)'
#  'Renfield -- Ursula Base (Yak sock)'
#  'The Fall of the House of Usher -- Carson Base (DK)'
#  'Wuthering Heights -- Carson Base (DK)'
#  'The Timekeeper -- Solnit Base (Sock)'
#  'Exquisite Corpse -- Carson Base (DK)' 'You Burn Me -- Carson Base (DK)'
#  'Eliza Furnace -- Ursula Base (Yak sock)'
#  'Eliza Furnace -- Anaïs Base (silk/merino single ply)'
#  'Fahrenheit 451 -- Carson Base (DK)'
#  'Lavender Leotard -- Carson Base (DK)'
#  'Dracula -- Ursula Base (yak sock)' 'Renfield -- Carson Base (DK)'
#  'The Yellow Wallpaper -- Carson Base (DK)'
#  'Dracula -- Solnit Base (sock)' 'House of Leaves -- Tartt Base (Bulky)'
#  'The Blue Aspic -- Tartt Base (Bulky)'
#  'The Fall of the House of Usher -- Tartt Base (Bulky)'
#  'Mina Murray -- Tartt Base (Bulky)' 'Topiary -- Tartt Base (Bulky)'
#  'Foxing -- Carson Base (DK)'
#  'The Picture of Dorian Gray -- Tartt Base (Bulky)'
#  'Abyss of Indiscretion -- Tartt Base (Bulky)'
#  'Fahrenheit 451 -- Tartt Base (Bulky)'
#  'Wraith Tea no. 44 -- Solnit Base (Sock)'
#  'Wraith Tea no. 43 -- Carson Base (DK)'
#  'Eliza Furnace -- Tartt Base (Bulky)' 'Dracula -- Tartt Base (Bulky)'
#  'The Willows -- Ursula Base (Yak sock)'
#  'Wuthering Heights -- Tartt Base (Bulky)'
#  'Wuthering Heights -- Ursula Base (Yak sock)'
#  'Exquisite Corpse -- Tartt Base (Bulky)'
#  'Sinister Premonitions -- Ursula Base (yak sock)'
#  'Mrs. Dalloway -- Ursula Base (Yak Sock)'
#  'The Yellow Wallpaper -- Ursula Base (Yak sock)' 'Fear Street Fade Set'
#  'Exquisite Corpse -- Anaïs Base (Silk/merino single ply)'
#  'Beastly countdown mini set (PREORDERS)'
#  'Wraith Tea no. 45 -- Jane Base (Superwash Merino/Silk Fingering)'
#  'Grackle -- Anaïs Base (Silk/merino single ply)'
#  'The Picture of Dorian Gray -- Anaïs Base (Silk/merino single ply)'
#  'Abyss of Indiscretion -- Anaïs Base (Silk/merino single ply)'
#  'Mina Murray  -- Anaïs Base (Silk/merino single ply)'
#  'Renfield  -- Anaïs Base (Silk/merino single ply)'
#  'House of Leaves -- Anaïs Base (Silk/merino single ply)'
#  'Wuthering Heights -- Anais Base (Superwash Merino/Silk; Single Ply Fingering Weight)'
#  'Topiary -- Anaïs Base (Silk/merino single ply)'
#  'Wraith Tea no. 49 -- Solnit Base (Sock)'
#  'Dracula Lily -- Ursula Base (Yak Sock)'
#  'Exquisite Corpse -- Joyce Base (Sock)'
#  'The Spectral Collection -- Solnit Base (Sock)'
#  'Wraith Tea no. 48 -- US Merino/Nylon (Worsted)'
#  'The Lifted Veil -- Joyce Base (Sock)'
#  'Wraith Tea no. 47 -- Carson Base (DK)' 'Unicorn Overdye' 'Tip'
#  'Abysmal -- Anaïs Base (Single ply silk/merino)'
#  'Dracula -- Carson Base (DK)' 'Avocado -- Untreated merino (Worsted)'
#  'House of Leaves -- Untreated Tweed (Sport)'
#  'Corpse Flower -- Ursula Base (Yak Sock)' 'Topiary -- Joyce Base (Sock)'
#  'Wraith Tea no. 17 -- US Merino/Nylon (Worsted)'
#  'Iron Lilac  -- Untreated merino (Worsted)'
#  'House of Leaves -- Untreated US Wool (Sock)'
#  'The Picture of Dorian Gray -- Carson Base (DK)'
#  'Newsprint -- Solnit Base (Sock)' 'House of Leaves -- Carson Base (DK)'
#  'Space Opera sock set' 'Summer Scaries mini set'
#  'Newsprint -- Carson Base (DK)' 'Carmilla - DK (Undead club) PREORDER'
#  'Carmilla - Yak Sock (Undead club) PREORDER'
#  'Carmilla - Sock (Undead club) PREORDER'
#  'Carmilla - Worsted (Undead club) PREORDER' 'YBD - Solnit Sock'
#  'YBD - Carson DK'
#  'The Fall of the House of Usher -- Anaïs Base (Silk/merino single ply)'
#  'Anaïs Base (Silk/merino single ply)'
#  'The Lifted Veil -- Carson Base (DK)'
#  'Wraith Tea no. 46 -- Carson Base (DK)'
#  'Red Berry -- Hemp/Untreated Merino (Sport)'
#  'The Lifted Veil -- Anaïs Base (Silk/merino single ply)'
#  'Pop Up - Carson DK' 'Pop Up - Sock Minis' 'Hemp' 'Evil garden'
#  'Pop Up - Solnit Sock' 'Green hemp' 'Pop Up - Sale bin' 'Bookish sticker'
#  'Bury Me in Books and Yarn sticker'
#  'Marble Staircase -- Joyce Base (Sock)'
#  'Glass-Floored Stacks -- Joyce Base (Sock)'
#  'Rusted Shelves -- Joyce Base (Sock)'
#  'Mrs. Dalloway -- Anaïs Base (Silk/merino single ply)'
#  'Archaic Rumors -- Shirley Base (Fingering)'
#  'Glass-Floored Stacks -- Solnit Base (Sock)'
#  'Archaic Rumors -- Solnit Base (Sock)'
#  'Rusted Shelves -- Solnit Base (Sock)'
#  'Ordinary Evils -- Shirley Base (Fingering)'
#  'Cultish -- Shirley Base (Fingering)'
#  'Marble Staircase -- Solnit Base (Sock)'
#  'Ordinary Evils -- Carson Base (DK)' 'Rusted Shelves -- Carson Base (DK)'
#  'Cultish -- Joyce Base (Sock)' 'Archaic Rumors -- Carson Base (DK)'
#  'Ordinary Evils -- Joyce Base (Sock)'
#  'Glass-Floored Stacks -- Carson Base (DK)'
#  'Archaic Rumors -- Joyce Base (Sock)' 'Bunny  -- Joyce Base (Sock)'
#  'Marble Staircase -- Shirley Base (Fingering)'
#  'PREORDERS - Domestic bases' 'Wraith Tea no. 49 -- Carson Base (DK)'
#  'Wraith Tea No. 50 -- Joyce Base (Sock)'
#  'Glass-Floored Stacks -- Shirley Base (Fingering)'
#  'Rusted Shelves -- Shirley Base (Fingering)'
#  'PREORDERS - DK, Sock, Yak Sock'
#  'Abyss of Indiscretion -- Solnit Base (Sock)'
#  'Marble Staircase -- Carson Base (DK)'
#  'Steel Blue -- Hemp/Untreated Merino (Sport)'
#  'Varney - Sock (Undead club) PREORDER'
#  'Varney- Yak Sock (Undead club) PREORDER'
#  'Varney - Worsted (Undead club) PREORDER'
#  'Varney - DK (Undead club) PREORDER' 'Sock Minis (POS)' 'Carson DK (POS)'
#  'Tarot pouch' 'Solnit Sock (POS)' 'Illuminated -- Solnit Base (Sock)'
#  'Witchgarden Flowers -- Solnit Base (Sock)' 'Cultish -- Carson Base (DK)'
#  'Bitchcraft -- Solnit Base (Sock)'
#  'Abyss of Indiscretion -- Carson Base (DK)'
#  'Wraith Tea no. 54 -- Carson (DK)' 'Wraith Tea no. 52 (Various Bases)'
#  'Witchgarden Flowers -- Carson Base (DK)'
#  'Sinister Premonitions -- Solnit Base (Sock)'
#  'Dracula -- Anaïs Base (Silk/merino single ply)'
#  'Wraith Tea no. 53 (Various Bases)' 'Night Magic -- Solnit Base (Sock)'
#  'Silver -- Hemp/Untreated Merino (Sport)' 'Halloween Mini Sets'
#  'Wraith Tea no. 51 (Various Bases)'
#  'Your Mother Sews Socks in Hell -- Solnit Base (Sock)'
#  'Sweet Suffering -- Solnit Base (Sock)' 'Wolfen -- Solnit Base (Sock)'
#  'Sweet Suffering -- Carson Base (DK)'
#  'The Forbidden -- Solnit Base (Sock)'
#  'Let the Right One In -- Solnit Base (Sock)'
#  'Your Mother Sews Socks in Hell -- Carson Base (DK)'
#  'The Forbidden -- Carson Base (DK)' 'Wolfen -- Carson Base (DK)'
#  'Sweet Suffering -- Zilpha Base (Worsted)'
#  'Let the Right One In -- Carson Base (DK)'
#  'Let the Right One In -- Zilpha Base (Worsted)'
#  'Illuminated -- Shirley Base (Fingering)' 'Bunny -- Solnit Base (Sock)'
#  'The Vampyre - Yak Sock (Undead club) PREORDER'
#  'The Vampyre - Sock (Undead club) PREORDER'
#  'The Vampyre - DK (Undead club) PREORDER'
#  'Villainous! -- Carson Base (DK)' 'Baba Yaga -- Carson Base (DK)'
#  'Baba Yaga -- Solnit Base (DK)' 'The Juniper Tree sock set'
#  'Villainous! -- Solnit Base (Sock)' "Grimms' Fairy Tales mini set"
#  'POS - Hats (machine)' 'POS - Dracula Sock Set' 'POS - Stickers'
#  'Wolfen -- Zilpha Base (Worsted)' 'Bunny -- Carson Base (DK)'
#  'Night Magic -- Carson Base (DK)' 'Dracula Sock Set' 'Stickers'
#  'Bunny -- Shirley Base (Fingering)' 'Secret Histories Mini Set'
#  'Shelley (Domestic worsted, NSW)' 'Shirley (Domestic fingering weight)'
#  'Sea Witch -- Joyce Base (Sock)' 'Carson (DK)' 'Hats (machine)'
#  'Archaic Rumors -- Ursula Base (Yak Sock)'
#  'Baba Yaga -- Solnit Base (Sock)' 'Progress Keepers'
#  'Eliza Furnace -- Carson Base (DK)'
#  'The Forbidden -- Zilpha Base (Worsted)'
#  'Your Mother Sews Socks in Hell -- Zilpha Base (Worsted)'
#  'Illuminated -- Joyce Base (Sock)' 'Mrs. Dalloway -- Joyce Base (Sock)'
#  'PREORDERS - Bulky' 'Sea Witch -- Carson Base (DK)'
#  'Necromancing (Various Bases)' 'Necromancer Sock Set'
#  'Hats (machine knit)' 'Illuminated -- Shelley Base (Worsted)'
#  'Rusted Shelves -- Shelley Base (Worsted)' 'Krampusnacht mini set'
#  'Cultish -- Shelley Base (Worsted)'
#  'Archaic Rumors -- Shelley Base (Worsted)'
#  'Tell-Tale -- Shirley Base (Fingering)'
#  'It Was His Eye! -- Shirley Base (Fingering)' 'Gaze Cowl Kit'
#  'Ordinary Evils -- Shelley Base (Worsted)' 'PREORDERS - Anaïs'
#  'Marble Staircase -- Shelley Base (Worsted)'
#  'Secret Histories Mini Set (Solnit - Sock)'
#  'Wraith Tea no. 57 -- Tartt Base (Bulky)'
#  'Wraith Tea no. 56 -- Shelley Base (NSW Worsted)'
#  'Exquisite Corpse -- Shelley Base (NSW Worsted)'
#  'Iron Gall Ink -- Solnit Base (Sock)' 'Wraith Tea no. 59 -- Carson (DK)'
#  'Iron Gall Ink -- Shelley Base (NSW Worsted)'
#  'Mina Murray -- Shelley Base (NSW Worsted)'
#  'Iron Gall Ink -- Zilpha Base (Worsted)'
#  'Wraith Tea no. 55 -- Ursula Base (Yak Sock)'
#  'Iron Gall Ink -- Carson Base (DK)'
#  'House of Leaves -- Zilpha Base (Worsted)'
#  'Dracula -- Zilpha Base (Worsted)'
#  'Wraith Tea no. 58 -- Tartt Base (Bulky)'
#  'Ordinary Evils -- Zilpha Base (Worsted)'
#  'The Picture of Dorian Gray -- Solnit Base (Sock)'
#  'Overstory -- Solnit Base (Sock)' 'Illuminated -- Carson Base (DK 115)'
#  'Pop Up Sale' 'Wraith Tea no. 62 -- Anaïs Base (Silk/merino single ply)'
#  'Wraith Tea no. 63 -- Zilpha Base (Worsted)'
#  'Wraith Tea no. 64 -- Shelley Base (NSW Worsted)'
#  'Wraith Tea no. 63 -- Anaïs Base (Silk/merino single ply)'
#  'Wraith Tea no. 61 -- Ursula Base (Yak Sock)'
#  'Overstory -- Zilpha Base (Worsted)'
#  'Wraith Tea no. 60 -- Tartt Base (Bulky)'
#  'Wraith Tea no. 62 -- Zilpha Base (Worsted)'
#  'Solnit (Sock) - Yarncentrick' 'Ursula (Yak Sock) - Yarncentrick'
#  'Undead mini set' 'Carson (DK) - Yarncentrick'
#  'Zilpha (Worsted) - Yarncentrick'
#  'Shelley (Light Worsted) - Yarncentrick'
#  'PREORDERS: Scary Stories - Halloween Mystery Countdown'
#  'Stickers - Pop Up' 'Ursula (Yak Sock) - Pop Up' 'Solnit (Sock) - Pop Up'
#  'Carson (DK) - Pop Up' 'Zilpha (Worsted) - Pop Up'
#  'Shelley (Light Worsted) - Pop Up' 'Undead mini set - Solnit base (Sock)'
#  'Varney the Vampire -- Carson Base (DK)' 'Carmilla -- Carson Base (DK)'
#  'Undead mini set - Ursula base (Yak Sock)'
#  'Ellenore -- Solnit Base (Sock)' 'Lord Ruthven -- Solnit Base (sock)'
#  'Varney the Vampyre -- Solnit Base (sock)'
#  'Dracula -- Shelley Base (NSW Worsted)'
#  'Mina Murray -- Ursula Base (Yak sock)'
#  'Cultish -- Zilpha Base (Worsted)'
#  'The Picture of Dorian Gray -- Zilpha Base (Worsted)'
#  'Lord Ruthven -- Carson Base (DK)' 'Overstory -- Carson Base (DK)'
#  'Illuminated -- Shelley Base (NSW Worsted)'
#  'Queer Classics Sets & Skeins' 'Baba Yaga -- Ursula Base (yak sock)'
#  'Vasilisa -- Solnit Base (Sock)' 'Ellenore -- Carson Base (DK)'
#  'Baba Yaga -- Zilpha Base (Worsted)'
#  'Exquisite Corpse -- Ursula Base (Yak Sock)'
#  'Vasilisa -- Carson Base (DK)' 'Aniline Black -- Ursula Base (yak sock)'
#  'Aniline Black -- Solnit Base (Sock)'
#  'Iron Gall Ink -- Ursula Base (yak sock)'
#  'Lord Ruthven -- Ursula Base (yak sock)' 'Fin de Siècle - sock & DK'
#  'Mrs. Dalloway -- Carson Base (DK)' 'Yarn Pick Ups'
#  'Renfield -- Shelley Base (NSW Worsted)'
#  'Scentless Apprentice - Solnit Base (Sock)'
#  'Lord Ruthven -- Zilpha Base (Worsted)'
#  'Aniline Black -- Carson Base (DK)' 'Cultish -- Ursula Base (yak sock)'
#  'House of Leaves -- Shelley Base (NSW Worsted)'
#  'Carmilla -- Zilpha Base (Worsted)' 'Carmilla -- Solnit Base (sock)'
#  'Wraith Tea no. 55 -- Carson (DK)' 'Sale Bin'
#  'The Lifted Veil -- Solnit Base (Sock)' 'Illuminated -- Carson Base (DK)'
#  'Ordinary Evils -- Solnit Base (Sock)'
#  'Fin de Siècle Mini Set -- Solnit Base (Sock)'
#  'Drawing Blood -- Carson Base (DK)' 'Stale Patchouli -- Carson Base (DK)'
#  'Early Grave -- Carson Base (DK)' 'Electronic Tears -- Carson Base (DK)'
#  'Lavender Leotard -- Ursula Base (Yak sock)'
#  'Hate Machine -- Solnit Base (Sock)' 'Hate Machine -- Carson Base (DK)'
#  'Circuit Decay -- Solnit Base (Sock)' 'Early Grave -- Solnit Base (Sock)'
#  'Drawing Blood -- Solnit Base (Sock)'
#  'Fin de Siècle Mini Set -- Ursula Base (Yak Sock)'
#  'Stale Patchouli -- Solnit Base (Sock)' 'Drowsy Hour -- Carson Base (DK)'
#  'Electronic Tears -- Solnit Base (Sock)'
#  'Rusted Shelves -- Shelley Base (NSW Worsted)'
#  'Varney the Vampire -- Ursula Base (yak sock)'
#  'Circuit Decay -- Carson Base (DK)' 'Drowsy Hour -- Solnit Base (Sock)'
#  'Glass-Floored Stacks -- Shelley Base (NSW Worsted)'
#  'Marble Staircase -- Shelley Base (NSW Worsted)']

# %%
sales_df['Product type'].unique()
# Out:
# array(['Hand Dyed Yarn', nan, 'Monthly Yarn Club', 'Gift Card', 'Notions',
#        'Gift Cards', 'Yarn', 'Handknits', 'sticker'], dtype=object)

# %% [markdown]
# ## 4 Cleanup

# %%
# investigate in dummy df
product_nan = sales_df[sales_df['Product type'].isna()]
product_nan.head()
# Out:
#          Order ID                      Date Transaction type Sale type  \
# 1   2468022255679 2020-08-09 00:00:19+00:00         shipping     order
# 3   2468022255679 2020-08-09 00:03:42+00:00         shipping    return
# 6   2469497241663 2020-08-09 16:04:57+00:00         shipping     order
# 9   2469499076671 2020-08-09 16:05:59+00:00         shipping     order
# 11  2469572509759 2020-08-09 16:38:24+00:00         shipping     order
#
#    Sales channel Product type Product  Net quantity  Gross sales  Discounts  \
# 1   Online Store          NaN     NaN             0          0.0        0.0
# 3   Online Store          NaN     NaN             0          0.0        0.0
# 6   Online Store          NaN     NaN             0          0.0        0.0
# 9   Online Store          NaN     NaN             0          0.0        0.0
# 11  Online Store          NaN     NaN             0          0.0        0.0
#
#     Returns  Net sales  Shipping
# 1       0.0        0.0      3.71
# 3       0.0        0.0     -3.71
# 6       0.0        0.0      5.58
# 9       0.0        0.0      4.43
# 11      0.0        0.0      8.34

# %%
product_nan['Transaction type'].unique()
# Out:
# array(['shipping', 'unknown', 'tip', 'product'], dtype=object)

# %%
product_nan['Transaction type'].value_counts(ascending=False)
# Out:
# shipping    916
# product     284
# unknown      11
# tip           7
# Name: Transaction type, dtype: int64

# %%
product_nan.loc[(product_nan['Transaction type'] == 'unknown')]
# Out:
#            Order ID                      Date Transaction type Sale type  \
# 321   3064403919023 2020-11-15 20:26:51+00:00          unknown    return
# 322   3064410276015 2020-11-15 20:27:36+00:00          unknown    return
# 535   3222346793135 2021-01-31 18:47:29+00:00          unknown    return
# 783   3752190509231 2021-04-16 12:00:38+00:00          unknown    return
# 1050  3979102355631 2021-07-17 10:30:18+00:00          unknown    return
# 2017  4802398322863 2022-10-12 17:44:54+00:00          unknown    return
# 2020  4802398322863 2022-10-18 13:30:23+00:00          unknown    return
# 2602  5145544589487 2023-03-31 15:47:42+00:00          unknown    return
# 2604  5145544589487 2023-03-31 15:47:42+00:00          unknown    return
# 2929  5265054335151 2023-06-01 18:11:07+00:00          unknown    return
# 2930  5265054335151 2023-06-01 18:11:07+00:00          unknown    return
#
#      Sales channel Product type Product  Net quantity  Gross sales  Discounts  \
# 321   Online Store          NaN     NaN             0          0.0        0.0
# 322   Online Store          NaN     NaN             0          0.0        0.0
# 535   Online Store          NaN     NaN             0          0.0        0.0
# 783   Online Store          NaN     NaN             0          0.0        0.0
# 1050  Online Store          NaN     NaN             0          0.0        0.0
# 2017  Online Store          NaN     NaN             0          0.0        0.0
# 2020  Online Store          NaN     NaN             0          0.0        0.0
# 2602  Online Store          NaN     NaN             0          0.0        0.0
# 2604  Online Store          NaN     NaN             0          0.0        0.0
# 2929  Online Store          NaN     NaN             0          0.0        0.0
# 2930  Online Store          NaN     NaN             0          0.0        0.0
#
#       Returns  Net sales  Shipping
# 321     -5.60      -5.60       0.0
# 322    -11.20     -11.20       0.0
# 535     -6.00      -6.00       0.0
# 783    -16.20     -16.20       0.0
# 1050   -14.40     -14.40       0.0
# 2017    10.18      10.18       0.0
# 2020   -10.18     -10.18       0.0
# 2602    -8.97      -8.97       0.0
# 2604     8.97       8.97       0.0
# 2929     8.69       8.69       0.0
# 2930    -8.69      -8.69       0.0

# %%
# If I replace Transaction type == 'unknown' with Transaction type == 'return', 
# I can use Transaction Type to fill in Product Type nans and possibly Product nans as well

product_nan['Transaction type'].replace('unknown', 'return', inplace=True)
product_nan['Transaction type'].unique()
# Out:
# C:\Users\miran\AppData\Local\Temp\ipykernel_5688\4230026193.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_nan['Transaction type'].replace('unknown', 'return', inplace=True)
# array(['shipping', 'return', 'tip', 'product'], dtype=object)

# %%
product_nan.loc[(product_nan['Transaction type'] == 'product')]
# Out:
#            Order ID                      Date Transaction type Sale type  \
# 1775  4789968502959 2022-08-26 22:06:55+00:00          product     order
# 1777  4789984329903 2022-08-26 22:18:41+00:00          product     order
# 1785  4790036922543 2022-08-26 23:02:17+00:00          product     order
# 1791  4790066380975 2022-08-26 23:27:32+00:00          product     order
# 1792  4790066380975 2022-08-26 23:27:32+00:00          product     order
# ...             ...                       ...              ...       ...
# 3060  5369765789871 2023-08-01 15:40:01+00:00          product     order
# 3095  5371475296431 2023-08-02 15:50:57+00:00          product     order
# 3096  5371475296431 2023-08-02 15:50:57+00:00          product     order
# 3101  5378258174127 2023-08-06 23:05:16+00:00          product     order
# 3106  5383798063279 2023-08-10 13:50:57+00:00          product     order
#
#      Sales channel Product type                            Product  \
# 1775     Yarn Fair          NaN                               Hemp
# 1777     Yarn Fair          NaN                        Evil garden
# 1785     Yarn Fair          NaN                         Green hemp
# 1791     Yarn Fair          NaN                    Bookish sticker
# 1792     Yarn Fair          NaN  Bury Me in Books and Yarn sticker
# ...            ...          ...                                ...
# 3060     Yarn Fair          NaN                      Yarn Pick Ups
# 3095  Online Store          NaN   Wraith Tea no. 55 -- Carson (DK)
# 3096  Online Store          NaN                    Bookish sticker
# 3101     Yarn Fair          NaN                           Sale Bin
# 3106  Online Store          NaN  Bury Me in Books and Yarn sticker
#
#       Net quantity  Gross sales  Discounts  Returns  Net sales  Shipping
# 1775             1         21.0      -3.15      0.0      17.85       0.0
# 1777             1         13.0       0.00      0.0      13.00       0.0
# 1785             1         21.0       0.00      0.0      21.00       0.0
# 1791             1          3.0       0.00      0.0       3.00       0.0
# 1792             1          3.0       0.00      0.0       3.00       0.0
# ...            ...          ...        ...      ...        ...       ...
# 3060             4        108.0       0.00      0.0     108.00       0.0
# 3095             2         54.0       0.00      0.0      54.00       0.0
# 3096             1          4.0       0.00      0.0       4.00       0.0
# 3101             2         26.0       0.00      0.0      26.00       0.0
# 3106             1          4.0       0.00      0.0       4.00       0.0
#
# [284 rows x 13 columns]

# %%
product_nan['Product type'] = np.where(product_nan['Product type'].isna(), product_nan['Transaction type'], 
                                       product_nan['Product type'])

product_nan['Product type'].unique()
# Out:
# C:\Users\miran\AppData\Local\Temp\ipykernel_5688\2168730952.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_nan['Product type'] = np.where(product_nan['Product type'].isna(), product_nan['Transaction type'],
# array(['shipping', 'return', 'tip', 'product'], dtype=object)

# %%
product_nan['Product'] = np.where(product_nan['Product'].isna(), product_nan['Transaction type'], 
                                       product_nan['Product'])
product_nan.isna().sum()
# Out:
# C:\Users\miran\AppData\Local\Temp\ipykernel_5688\3582615689.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_nan['Product'] = np.where(product_nan['Product'].isna(), product_nan['Transaction type'],
# Order ID            0
# Date                0
# Transaction type    0
# Sale type           0
# Sales channel       0
# Product type        0
# Product             0
# Net quantity        0
# Gross sales         0
# Discounts           0
# Returns             0
# Net sales           0
# Shipping            0
# dtype: int64

# %%
#after exploring, update data in sales_df
sales_df['Transaction type'].replace('unknown', 'return', inplace=True)
sales_df['Product type'] = np.where(sales_df['Product type'].isna(), sales_df['Transaction type'], 
                                       sales_df['Product type'])
sales_df['Product'] = np.where(sales_df['Product'].isna(), sales_df['Transaction type'], 
                                       sales_df['Product type'])

# %%
sales_df.isna().sum()
# Out:
# Order ID            0
# Date                0
# Transaction type    0
# Sale type           0
# Sales channel       0
# Product type        0
# Product             0
# Net quantity        0
# Gross sales         0
# Discounts           0
# Returns             0
# Net sales           0
# Shipping            0
# dtype: int64

# %% [markdown]
# ## 5 "Save As"

# %%
# save dataframe without overwriting the original data in order to preserve integrity

os.makedirs('C:/Users/miran/Desktop/Ex Libris Fibers', exist_ok=True)  
sales_df.to_csv('C:/Users/miran/Desktop/Ex Libris Fibers/sales_df.csv')
